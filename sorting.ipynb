# %% [markdown]
# # bubble sort
#
# The most popular and simple sorting algorithm
# it compares adjacent elements, and swaps them if they are in the wrong order

# %%
def bubble_sort(a: list) -> list:
    n = len(a)
    for i in range(n-1):
        for j in range(n - i - 1):
            if a[j] > a[j+1]:
                a[j], a[j+1] = a[j+1], a[j]
    return a


print(bubble_sort([4,6,7,3,5]))
# Out:
# [3, 4, 5, 6, 7]

# %% [markdown]
# # Selection sort algorithm
#
# sorts by repeatedly finding the minimum element

# %%
def selection_sort(a: list) -> list:
    n = len(a)
    for i in range(n-1):
        min_index = i
        for j in range(i + 1, n):
            if a[j] < a[min_index]:
                min_index = j
        a[i], a[min_index] = a[min_index], a[i]
    return a

print(selection_sort([4,6,7,3,5]))
# Out:
# [3, 4, 5, 6, 7]
